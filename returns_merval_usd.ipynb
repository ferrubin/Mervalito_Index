# %% [markdown]
# # Mapa de Calor de Variaciones Mensuales para ^Merv en USD (CCL YPF)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Crear el DataFrame con todos los datos
data = {
   'Año': range(2007, 2025),
   'Ene': [-1.99, -12.04, -0.41, -7.35, -1.14, 14.10, 7.96, -19.34, -5.99, -3.15, 15.14, 11.20, 24.24, -14.87, -17.23, -2.64, 17.64, 4.34],
   'Feb': [6.70, 6.15, -12.33, -2.00, -5.75, -6.58, -23.22, 15.12, 16.24, 1.86, 2.72, -8.00, -10.18, -11.40, 9.60, 7.35, -3.09, -4.05],
   'Mar': [3.31, -1.61, 11.20, 5.94, -0.30, -6.65, 15.33, 11.69, 12.05, 7.24, 6.21, -5.03, -12.65, -32.73, 0.48, 8.62, -9.16, 16.59],
   'Abr': [3.63, 0.29, 11.68, 3.57, -3.80, -18.34, 5.51, 7.37, 13.60, 8.00, 2.94, -6.19, -13.24, 1.72, -4.70, -10.83, 6.98, 8.04],
   'May': [-2.49, 4.27, 22.52, -10.40, -1.91, -15.87, -2.22, 4.53, -9.74, -4.85, 2.27, -20.99, 13.86, 17.08, 18.20, 3.42, 7.40, 9.45],
   'Jun': [-3.39, -3.38, -1.96, -2.05, 7.46, -0.21, -6.84, 9.03, -1.55, 7.27, -4.84, -20.68, 28.53, 8.80, -0.56, -21.50, 19.00, -9.95],
   'Jul': [-4.68, -3.71, 8.66, 13.67, -0.85, -4.82, 6.53, 6.11, -7.84, 6.60, -7.07, 18.87, -3.07, 9.25, -1.22, 20.71, -0.24, -3.68],
   'Ago': [4.35, -9.37, 3.51, -6.17, -15.43, 10.28, 9.43, -6.34, -4.29, -0.10, 10.40, -27.43, -59.77, -10.52, 18.99, 12.03, 0.37, 11.66],
   'Sep': [7.48, -9.96, 19.50, 14.38, -27.65, 4.14, 19.82, 8.23, -12.41, 5.23, 10.72, 2.64, 19.28, -21.07, -9.10, -4.47, -17.26, None],
   'Oct': [-2.00, -41.12, 3.11, 14.75, 17.83, -11.35, 4.17, 1.38, 31.40, 6.64, 5.57, 1.70, -4.28, 0.23, 0.82, 8.98, -2.88, None],
   'Nov': [-1.48, 1.25, -0.22, 6.68, 2.58, 4.74, 22.26, -1.91, -3.13, -5.72, -1.08, 3.56, 5.75, 25.52, -6.12, 5.55, 40.00, None],
   'Dic': [0.0, 5.15, 12.86, 7.10, -10.65, 16.28, -10.37, -11.41, -5.91, -4.94, 1.35, -6.72, 22.34, 0.87, 12.29, 14.46, 2.43, None]
}


df = pd.DataFrame(data)


# Configurar el índice del DataFrame como el año
df.set_index('Año', inplace=True)


# Crear un mapa de calor
plt.figure(figsize=(20, 12))
sns.heatmap(df, annot=True, cmap='RdYlGn', center=0, fmt='.2f', mask=df.isnull())
plt.title('Mapa de Calor de Variaciones Mensuales para ^Merv en USD (CCL YPF)')
plt.show()

# %% [markdown]
# # Posibles Retornos

# %%
import pandas as pd
import numpy as np

# Crear el DataFrame con los datos (el mismo del ejemplo anterior)
data = {
    'Año': range(2007, 2025),
    'Ene': [-1.99, -12.04, -0.41, -7.35, -1.14, 14.10, 7.96, -19.34, -5.99, -3.15, 15.14, 11.20, 24.24, -14.87, -17.23, -2.64, 17.64, 4.34],
    'Feb': [6.70, 6.15, -12.33, -2.00, -5.75, -6.58, -23.22, 15.12, 16.24, 1.86, 2.72, -8.00, -10.18, -11.40, 9.60, 7.35, -3.09, -4.05],
    'Mar': [3.31, -1.61, 11.20, 5.94, -0.30, -6.65, 15.33, 11.69, 12.05, 7.24, 6.21, -5.03, -12.65, -32.73, 0.48, 8.62, -9.16, 16.59],
    'Abr': [3.63, 0.29, 11.68, 3.57, -3.80, -18.34, 5.51, 7.37, 13.60, 8.00, 2.94, -6.19, -13.24, 1.72, -4.70, -10.83, 6.98, 8.04],
    'May': [-2.49, 4.27, 22.52, -10.40, -1.91, -15.87, -2.22, 4.53, -9.74, -4.85, 2.27, -20.99, 13.86, 17.08, 18.20, 3.42, 7.40, 9.45],
    'Jun': [-3.39, -3.38, -1.96, -2.05, 7.46, -0.21, -6.84, 9.03, -1.55, 7.27, -4.84, -20.68, 28.53, 8.80, -0.56, -21.50, 19.00, -9.95],
    'Jul': [-4.68, -3.71, 8.66, 13.67, -0.85, -4.82, 6.53, 6.11, -7.84, 6.60, -7.07, 18.87, -3.07, 9.25, -1.22, 20.71, -0.24, -3.68],
    'Ago': [4.35, -9.37, 3.51, -6.17, -15.43, 10.28, 9.43, -6.34, -4.29, -0.10, 10.40, -27.43, -59.77, -10.52, 18.99, 12.03, 0.37, 11.66],
    'Sep': [7.48, -9.96, 19.50, 14.38, -27.65, 4.14, 19.82, 8.23, -12.41, 5.23, 10.72, 2.64, 19.28, -21.07, -9.10, -4.47, -17.26, None],
    'Oct': [-2.00, -41.12, 3.11, 14.75, 17.83, -11.35, 4.17, 1.38, 31.40, 6.64, 5.57, 1.70, -4.28, 0.23, 0.82, 8.98, -2.88, None],
    'Nov': [-1.48, 1.25, -0.22, 6.68, 2.58, 4.74, 22.26, -1.91, -3.13, -5.72, -1.08, 3.56, 5.75, 25.52, -6.12, 5.55, 40.00, None],
    'Dic': [0.0, 5.15, 12.86, 7.10, -10.65, 16.28, -10.37, -11.41, -5.91, -4.94, 1.35, -6.72, 22.34, 0.87, 12.29, 14.46, 2.43, None]
}

df = pd.DataFrame(data)
df.set_index('Año', inplace=True)

# Extraer los datos de septiembre y eliminar valores nulos
september_returns = df['Sep'].dropna()

# Calcular el promedio y la desviación estándar
september_mean = september_returns.mean()
september_std = september_returns.std()

# Imprimir el retorno promedio y el rango probable
print(f"Retorno promedio de septiembre: {september_mean:.2f}%")
print(f"Desviación estándar de septiembre: {september_std:.2f}%")

# Calcular el rango probable (promedio ± 1 desviación estándar)
lower_bound = september_mean - september_std
upper_bound = september_mean + september_std

print(f"Rango probable de retorno en septiembre: {lower_bound:.2f}% a {upper_bound:.2f}%")
# Out:
# Retorno promedio de septiembre: 0.56%
# Desviación estándar de septiembre: 14.79%
# Rango probable de retorno en septiembre: -14.23% a 15.35%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Crear el DataFrame con los datos
data = {
    'Año': range(2007, 2025),
    'Ene': [-1.99, -12.04, -0.41, -7.35, -1.14, 14.10, 7.96, -19.34, -5.99, -3.15, 15.14, 11.20, 24.24, -14.87, -17.23, -2.64, 17.64, 4.34],
    'Feb': [6.70, 6.15, -12.33, -2.00, -5.75, -6.58, -23.22, 15.12, 16.24, 1.86, 2.72, -8.00, -10.18, -11.40, 9.60, 7.35, -3.09, -4.05],
    'Mar': [3.31, -1.61, 11.20, 5.94, -0.30, -6.65, 15.33, 11.69, 12.05, 7.24, 6.21, -5.03, -12.65, -32.73, 0.48, 8.62, -9.16, 16.59],
    'Abr': [3.63, 0.29, 11.68, 3.57, -3.80, -18.34, 5.51, 7.37, 13.60, 8.00, 2.94, -6.19, -13.24, 1.72, -4.70, -10.83, 6.98, 8.04],
    'May': [-2.49, 4.27, 22.52, -10.40, -1.91, -15.87, -2.22, 4.53, -9.74, -4.85, 2.27, -20.99, 13.86, 17.08, 18.20, 3.42, 7.40, 9.45],
    'Jun': [-3.39, -3.38, -1.96, -2.05, 7.46, -0.21, -6.84, 9.03, -1.55, 7.27, -4.84, -20.68, 28.53, 8.80, -0.56, -21.50, 19.00, -9.95],
    'Jul': [-4.68, -3.71, 8.66, 13.67, -0.85, -4.82, 6.53, 6.11, -7.84, 6.60, -7.07, 18.87, -3.07, 9.25, -1.22, 20.71, -0.24, -3.68],
    'Ago': [4.35, -9.37, 3.51, -6.17, -15.43, 10.28, 9.43, -6.34, -4.29, -0.10, 10.40, -27.43, -59.77, -10.52, 18.99, 12.03, 0.37, 11.66],
    'Sep': [7.48, -9.96, 19.50, 14.38, -27.65, 4.14, 19.82, 8.23, -12.41, 5.23, 10.72, 2.64, 19.28, -21.07, -9.10, -4.47, -17.26, None],
    'Oct': [-2.00, -41.12, 3.11, 14.75, 17.83, -11.35, 4.17, 1.38, 31.40, 6.64, 5.57, 1.70, -4.28, 0.23, 0.82, 8.98, -2.88, None],
    'Nov': [-1.48, 1.25, -0.22, 6.68, 2.58, 4.74, 22.26, -1.91, -3.13, -5.72, -1.08, 3.56, 5.75, 25.52, -6.12, 5.55, 40.00, None],
    'Dic': [0.0, 5.15, 12.86, 7.10, -10.65, 16.28, -10.37, -11.41, -5.91, -4.94, 1.35, -6.72, 22.34, 0.87, 12.29, 14.46, 2.43, None]
}

df = pd.DataFrame(data)
df.set_index('Año', inplace=True)

# Extraer los datos de septiembre y eliminar valores nulos
september_returns = df['Sep'].dropna()

# Calcular el promedio y la desviación estándar
september_mean = september_returns.mean()
september_std = september_returns.std()

# Graficar la desviación estándar y el promedio
plt.figure(figsize=(10, 6))
years = september_returns.index
plt.plot(years, september_returns, marker='o', label='Retornos de septiembre')

# Graficar el promedio y el área de la desviación estándar
plt.axhline(september_mean, color='green', linestyle='--', label=f'Promedio ({september_mean:.2f}%)')
plt.fill_between(years, september_mean - september_std, september_mean + september_std, color='green', alpha=0.3, label=f'Rango de 1 Desviación Estándar')

# Personalizar la gráfica
plt.title('Retornos de septiembre con promedio y desviación estándar')
plt.xlabel('Año')
plt.ylabel('Retorno (%)')
plt.legend()
plt.grid(True)
plt.show()
